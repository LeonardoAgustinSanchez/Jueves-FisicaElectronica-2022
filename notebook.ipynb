# %% [markdown]
# <a href="https://colab.research.google.com/github/LeonardoAgustinSanchez/Jueves-FisicaElectronica-2022/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Intro a Jupyter Notebook con Google Colab
#
# Google Colab es la plataforma de Google para ejecutar Jupyter Notebooks. Se trata de una herramienta que hace uso de "celdas" o espacios para escribir código y metadata.
# <br> El objetivo de esto es integrar en un sólo lugar texto, código, imágenes y otras cosas para ayudar en la experimentación.
# <br>Jupyter Notebook es un entorno de desarrollo utilizado ampliamente en análisis numérico, estadística y machine learning, entre otros campos de la informática, las matemáticas y las ciencias en general.
# <br><br>
#
# ### Código y metadata
#
# En Google Colab, podemos definir celdas de "código" y celdas de "texto". Si generamos una celda de código, allí podremos escribir pequeños scripts y ejecutarlos. Estos scripts pueden ser tanto funciones larguísimas, como objetos si programamos con el paradigma POO o algo tan simple como una sóla linea de código que calcule la suma de 2 números.
#
# <br>En cambio, si generamos una celda de texto, podremos generar código "markdown", es decir, texto más algunos modificadores que permiten darle formato a ese texto.
#
# <br>De esta manera, creamos código y lo documentamos al mismo tiempo. ¡Esto es muy útil para experimentar y contar los resultados!
# <br><br>
#
# ### Código: ¿qué tipo de código y cómo se ejecuta?
#
# El lenguaje de programación defacto en Google Colab es Python 3. Anteriormente, se podía usar Python 2 pero al haberse deprecado, sólo se le da soporte a Python 3.
#
# <br>Cabe destacar que Python no es un lenguaje que requiera de un compilador, sino que se ejecuta con un runtime (también llamado "kernel"). Por lo que podemos cambiar el código y volver a correrlo sin necesidad de compilar (atención, para usar Python embebido <i>¡sí se debe compilar!</i>). En el menú "runtime" podemos configurar qué queremos correr (generalmente creamos código en varias celdas, por lo que podemos indicarle si queremos correr una sola, todas, a partir de cierta celda, etc).
#
# <br>Si lo que queremos es ejecutar una sóla celda, podemos hacerlo manteniendo presionado "shift" y dando "enter". Para las celdas de texto, la ejecución es necesaria sólo cuando hacemos un cambio (en la imagen de abajo se verá cómo veo yo el texto mientras lo escribo :-) ).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Ejemplo:
# Vamos a escuchar audios, los cuales importo como set de datos (en el universo digital, los audios son una colección de unos y ceros).

# %%
# tengo los audios en Google Drive, asi que cargo "drive" en "colab" (nota: uso el "wildcard" "#" para hacer comentarios)
# Google Drive pide un codigo para vincularse con Colab -es bastante simple-
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# si existieran carpetas viejas, las elimino, asi la demostracion sale limpia
# !rm -rf dataset

# %%
# los tengo comprimidos por lo que, los tengo que descomprimir (y ademas, hay un diccionario)
# esto introduce otro "wildcard" de Jupyter: el "!". Seguido a "!" puedo ejecutar un comando de bash (la linea de comandos de Unix)
! unzip '/content/drive/My Drive/Física Electrónica Catedra/11_Colab/01_intro/audios.zip'
# Out:
# Archive:  /content/drive/My Drive/Física Electrónica Catedra/11_Colab/01_intro/audios.zip
#    creating: dataset/
#    creating: dataset/audios/
#   inflating: dataset/.DS_Store
#   inflating: dataset/train.csv
#   inflating: dataset/audios/673acd6f.wav
#   inflating: dataset/audios/82c40c96.wav
#   inflating: dataset/audios/938869a6.wav
#   inflating: dataset/audios/bfb5b77c.wav
#   inflating: dataset/audios/5ae5198b.wav
#   inflating: dataset/audios/e3dbb572.wav
#   inflating: dataset/audios/94934bac.wav
#   inflating: dataset/audios/857e4f34.wav
#   inflating: dataset/audios/bfbda4bc.wav
#   inflating: dataset/audios/a8e4a91e.wav
#   inflating: dataset/audios/f0e7f5da.wav
#   inflating: dataset/audios/b56b8465.wav
#   inflating: dataset/audios/2ae9e186.wav
#   inflating: dataset/audios/04eb6226.wav
#   inflating: dataset/audios/a6665ed2.wav
#   inflating: dataset/audios/abc7ddef.wav
#   inflating: dataset/audios/5435ddab.wav
#   inflating: dataset/audios/f8ffc4fc.wav
#   inflating: dataset/audios/82f815c6.wav
#   inflating: dataset/audios/45940fd0.wav
#   inflating: dataset/audios/1fa867aa.wav
#   inflating: dataset/audios/73440c1f.wav
#   inflating: dataset/audios/22af36ad.wav
#   inflating: dataset/audios/f49eab9e.wav
#   inflating: dataset/audios/3d1b2f47.wav
#   inflating: dataset/audios/57f5f21b.wav
#   inflating: dataset/audios/97bb5eb0.wav
#   inflating: dataset/audios/86644708.wav
#   inflating: dataset/audios/a3222f41.wav
#   inflating: dataset/audios/6454762b.wav
#   inflating: dataset/audios/eddce22d.wav
#   inflating: dataset/audios/49cc7d13.wav
#   inflating: dataset/audios/1a598ecc.wav
#   inflating: dataset/audios/27b8aa89.wav
#   inflating: dataset/audios/49a9d143.wav
#   inflating: dataset/audios/03ea2668.wav
#   inflating: dataset/audios/50d1c179.wav
#   inflating: dataset/audios/bd438a05.wav
#   inflating: dataset/audios/f520d1e8.wav
#   inflating: dataset/audios/9f9535fb.wav
#   inflating: dataset/audios/5c4778cd.wav
#   inflating: dataset/audios/ed19cb7d.wav
#   inflating: dataset/audios/5c6f6103.wav
#   inflating: dataset/audios/beba9e15.wav
#   inflating: dataset/audios/8b2ed13a.wav
#   inflating: dataset/audios/34d26a2e.wav
#   inflating: dataset/audios/74541bc4.wav
#   inflating: dataset/audios/9f1f76ea.wav
#   inflating: dataset/audios/f6d1a5bd.wav
#   inflating: dataset/audios/fd273d55.wav
#   inflating: dataset/audios/db70946f.wav
#   inflating: dataset/audios/93997e8a.wav
#   inflating: dataset/audios/c0dce5bf.wav
#   inflating: dataset/audios/f5e962db.wav
#   inflating: dataset/audios/97f7cd56.wav
#   inflating: dataset/audios/.DS_Store
#   inflating: dataset/audios/eedff032.wav
#   inflating: dataset/audios/069d8df9.wav
#   inflating: dataset/audios/408dfb58.wav
#   inflating: dataset/audios/79b09200.wav
#   inflating: dataset/audios/7af5553f.wav
#   inflating: dataset/audios/0853e0df.wav
#   inflating: dataset/audios/f1a847da.wav
#   inflating: dataset/audios/c8184b62.wav
#   inflating: dataset/audios/3426759f.wav
#   inflating: dataset/audios/dbd399d7.wav
#   inflating: dataset/audios/ede8d21c.wav
#   inflating: dataset/audios/499c95f6.wav
#   inflating: dataset/audios/79852608.wav
#   inflating: dataset/audios/864d840f.wav
#   inflating: dataset/audios/7e6d295a.wav
#   inflating: dataset/audios/fc9f71b9.wav
#   inflating: dataset/audios/979728a5.wav
#   inflating: dataset/audios/e18e88f1.wav
#   inflating: dataset/audios/8d1d617a.wav
#   inflating: dataset/audios/fc8e862c.wav
#   inflating: dataset/audios/f2833124.wav
#   inflating: dataset/audios/6be5422e.wav
#   inflating: dataset/audios/da84ebf3.wav
#   inflating: dataset/audios/ae1d4d55.wav
#   inflating: dataset/audios/c20d1733.wav
#   inflating: dataset/audios/3ff8b27b.wav
#   inflating: dataset/audios/ec7d7266.wav
#   inflating: dataset/audios/bda07ed4.wav
#   inflating: dataset/audios/b523777c.wav
#   inflating: dataset/audios/eaef871f.wav
#   inflating: dataset/audios/cb359774.wav
#   inflating: dataset/audios/e15c5a89.wav
#   inflating: dataset/audios/7a443296.wav
#   inflating: dataset/audios/5b63cfce.wav
#   inflating: dataset/audios/96fde909.wav
#   inflating: dataset/audios/03f91aaf.wav
#   inflating: dataset/audios/f291b5f4.wav
#   inflating: dataset/audios/8ebeb89c.wav
#   inflating: dataset/audios/d0ba8b8a.wav
#   inflating: dataset/audios/830ec6e4.wav
#   inflating: dataset/audios/0026f116.wav
#   inflating: dataset/audios/38828531.wav
#   inflating: dataset/audios/5c3a13e0.wav
#   inflating: dataset/audios/9e5f8b92.wav
#   inflating: dataset/audios/4fbd90c3.wav
#   inflating: dataset/audios/cc800b86.wav
#   inflating: dataset/audios/d9833078.wav
#   inflating: dataset/audios/de4de5a3.wav
#   inflating: dataset/audios/1b1dc76c.wav
#   inflating: dataset/audios/b1854b62.wav
#   inflating: dataset/audios/c99f7507.wav
#   inflating: dataset/audios/bb44c157.wav
#   inflating: dataset/audios/bb61aa7a.wav
#   inflating: dataset/audios/2db2b9e8.wav
#   inflating: dataset/audios/8f237e57.wav
#   inflating: dataset/audios/c2ab759e.wav
#   inflating: dataset/audios/70b130c6.wav
#   inflating: dataset/audios/37dba7fa.wav
#   inflating: dataset/audios/55caac26.wav
#   inflating: dataset/audios/34cb4362.wav
#   inflating: dataset/audios/49c859d9.wav
#   inflating: dataset/audios/001ec0ad.wav
#   inflating: dataset/audios/8d112af4.wav
#   inflating: dataset/audios/775a890a.wav
#   inflating: dataset/audios/30662e2a.wav
#   inflating: dataset/audios/fd35acde.wav
#   inflating: dataset/audios/804af928.wav
#   inflating: dataset/audios/cf809980.wav
#   inflating: dataset/audios/35d474fc.wav
#   inflating: dataset/audios/b0191349.wav
#   inflating: dataset/audios/26213be3.wav
#   inflating: dataset/audios/c6a1d90c.wav
#   inflating: dataset/audios/c61682e1.wav
#   inflating: dataset/audios/e5c21d14.wav
#   inflating: dataset/audios/aa8d36ba.wav
#   inflating: dataset/audios/4b782e2e.wav
#   inflating: dataset/audios/e5805ab2.wav
#   inflating: dataset/audios/4b5d4bc7.wav
#   inflating: dataset/audios/ec642636.wav
#   inflating: dataset/audios/6e6f26bc.wav
#   inflating: dataset/audios/a6d71f37.wav
#   inflating: dataset/audios/919b6b3c.wav
#   inflating: dataset/audios/0daef120.wav
#   inflating: dataset/audios/c0eef722.wav
#   inflating: dataset/audios/9796192d.wav
#   inflating: dataset/audios/a9e97fb7.wav
#   inflating: dataset/audios/e989f9f4.wav
#   inflating: dataset/audios/6c8245bf.wav
#   inflating: dataset/audios/8728d69c.wav
#   inflating: dataset/audios/72fa928a.wav
#   inflating: dataset/audios/3ec7ee97.wav
#   inflating: dataset/audios/cb2c8e83.wav
#   inflating: dataset/audios/4202d212.wav
#   inflating: dataset/audios/76bf1389.wav
#   inflating: dataset/audios/aece8573.wav
#   inflating: dataset/audios/41d42589.wav
#   inflating: dataset/audios/310ef563.wav
#   inflating: dataset/audios/994728a8.wav
#   inflating: dataset/audios/20ae2882.wav
#   inflating: dataset/audios/99db7bfe.wav
#   inflating: dataset/audios/a5f3e527.wav
#   inflating: dataset/audios/ab0c7cec.wav
#   inflating: dataset/audios/958e80a2.wav
#   inflating: dataset/audios/09be0615.wav
#   inflating: dataset/audios/6473d6f0.wav
#   inflating: dataset/audios/21065bd2.wav
#   inflating: dataset/audios/323fe68f.wav
#   inflating: dataset/audios/0e2bd984.wav
#   inflating: dataset/audios/5748434e.wav
#   inflating: dataset/audios/4d5661e9.wav
#   inflating: dataset/audios/1829fa7f.wav
#   inflating: dataset/audios/71282096.wav
#   inflating: dataset/audios/a859d562.wav
#   inflating: dataset/audios/0ea2b567.wav
#   inflating: dataset/audios/d9a2bbd4.wav
#   inflating: dataset/audios/87e74683.wav
#   inflating: dataset/audios/ef2dac94.wav
#   inflating: dataset/audios/ac2cd845.wav
#   inflating: dataset/audios/42d9173e.wav
#   inflating: dataset/audios/d6eb1245.wav
#   inflating: dataset/audios/bfe4fb2f.wav
#   inflating: dataset/audios/34746b28.wav
#   inflating: dataset/audios/1f0aabd0.wav
#   inflating: dataset/audios/2f3750d3.wav
#   inflating: dataset/audios/236a3c5b.wav
#   inflating: dataset/audios/88bf48be.wav
#   inflating: dataset/audios/744449d8.wav
#   inflating: dataset/audios/b8530b6a.wav
#   inflating: dataset/audios/f604a8be.wav
#   inflating: dataset/audios/a8398ca8.wav
#   inflating: dataset/audios/2c4c8c2e.wav
#   inflating: dataset/audios/f6cb7750.wav
#   inflating: dataset/audios/2f1c4765.wav
#   inflating: dataset/audios/c78180ce.wav
#   inflating: dataset/audios/70bd30b7.wav
#   inflating: dataset/audios/48d8ca20.wav
#   inflating: dataset/audios/f686556a.wav
#   inflating: dataset/audios/f64b4c3c.wav
#   inflating: dataset/audios/a849d801.wav
#   inflating: dataset/audios/da10b0b4.wav
#   inflating: dataset/audios/554b49a5.wav
#   inflating: dataset/audios/733c6daa.wav
#   inflating: dataset/audios/88053677.wav
#   inflating: dataset/audios/fb4a6a7a.wav
#   inflating: dataset/audios/a153ba95.wav
#   inflating: dataset/audios/2842633f.wav
#   inflating: dataset/audios/0faeaee0.wav
#   inflating: dataset/audios/a5e2851f.wav
#   inflating: dataset/audios/ee6559a6.wav
#   inflating: dataset/audios/608e6f9d.wav
#   inflating: dataset/audios/9a22459e.wav
#   inflating: dataset/audios/5dba01d9.wav
#   inflating: dataset/audios/e9586170.wav
#   inflating: dataset/audios/afa527b3.wav
#   inflating: dataset/audios/32b3d1cc.wav
#   inflating: dataset/audios/dd1ef3b2.wav
#   inflating: dataset/audios/fe485cb6.wav
#   inflating: dataset/audios/be3e2862.wav
#   inflating: dataset/audios/7ec7c7fd.wav
#   inflating: dataset/audios/a383510c.wav
#   inflating: dataset/audios/1b3eca9e.wav
#   inflating: dataset/audios/5587fc83.wav
#   inflating: dataset/audios/35cb2141.wav
#   inflating: dataset/audios/2382e924.wav
#   inflating: dataset/audios/ae350ecf.wav
#   inflating: dataset/audios/3d43b112.wav
#   inflating: dataset/audios/344bc484.wav
#   inflating: dataset/audios/7755e21b.wav
#   inflating: dataset/audios/2ce5262c.wav
#   inflating: dataset/audios/25f91c87.wav
#   inflating: dataset/audios/256ca03e.wav
#   inflating: dataset/audios/030d5b55.wav
#   inflating: dataset/audios/f1015c40.wav
#   inflating: dataset/audios/6c6c57f2.wav
#   inflating: dataset/audios/bc3daf53.wav
#   inflating: dataset/audios/2a4385f4.wav
#   inflating: dataset/audios/27f74f04.wav
#   inflating: dataset/audios/8a05deba.wav
#   inflating: dataset/audios/77fd6b75.wav
#   inflating: dataset/audios/3f32d7cb.wav
#   inflating: dataset/audios/b0aa3d8c.wav
#   inflating: dataset/audios/6dbe898f.wav
#   inflating: dataset/audios/16316726.wav
#   inflating: dataset/audios/a926ff23.wav
#   inflating: dataset/audios/94a28428.wav
#   inflating: dataset/audios/e339765a.wav
#   inflating: dataset/audios/211717bf.wav
#   inflating: dataset/audios/d59e2ed2.wav
#   inflating: dataset/audios/d1af3039.wav
#   inflating: dataset/audios/a05d05d1.wav
#   inflating: dataset/audios/ad4fbd43.wav
#   inflating: dataset/audios/4f246773.wav
#   inflating: dataset/audios/8eb4452b.wav
#   inflating: dataset/audios/76ad78c3.wav
#   inflating: dataset/audios/cc7b400c.wav
#   inflating: dataset/audios/3caae121.wav
#   inflating: dataset/audios/50fa6fbd.wav
#   inflating: dataset/audios/0e7f526e.wav
#   inflating: dataset/audios/0f8eb9a4.wav
#   inflating: dataset/audios/84fadbf3.wav
#   inflating: dataset/audios/9f955137.wav
#   inflating: dataset/audios/47b76d15.wav
#   inflating: dataset/audios/10c821a2.wav
#   inflating: dataset/audios/b50e3ef6.wav
#   inflating: dataset/audios/1c46064a.wav
#   inflating: dataset/audios/dbb59c2c.wav
#   inflating: dataset/audios/bf647bef.wav
#   inflating: dataset/audios/fc01bdda.wav
#   inflating: dataset/audios/7337c74a.wav
#   inflating: dataset/audios/6652984c.wav
#   inflating: dataset/audios/5d98819d.wav
#   inflating: dataset/audios/c004299e.wav
#   inflating: dataset/audios/70cf4de7.wav
#   inflating: dataset/audios/2e8763ab.wav
#   inflating: dataset/audios/e271395a.wav
#   inflating: dataset/audios/f88f7c6d.wav
#   inflating: dataset/audios/b52d7a5f.wav
#   inflating: dataset/audios/9a5ef104.wav
#   inflating: dataset/audios/dba11d27.wav
#   inflating: dataset/audios/7e5495f8.wav
#   inflating: dataset/audios/037b9243.wav
#   inflating: dataset/audios/0595bce6.wav
#   inflating: dataset/audios/6b761c00.wav
#   inflating: dataset/audios/567cfc15.wav
#   inflating: dataset/audios/076f25a3.wav
#   inflating: dataset/audios/7654ee3e.wav
#   inflating: dataset/audios/07d58bea.wav
#   inflating: dataset/audios/781c102a.wav
#   inflating: dataset/audios/8098514c.wav
#   inflating: dataset/audios/f65784cc.wav
#   inflating: dataset/audios/4776db7d.wav
#   inflating: dataset/audios/97b783cf.wav
#   inflating: dataset/audios/192bacfd.wav
#   inflating: dataset/audios/aec32e4d.wav
#   inflating: dataset/audios/cc8555d3.wav
#   inflating: dataset/audios/07cc5d69.wav
#   inflating: dataset/audios/de14cce1.wav
#   inflating: dataset/audios/a58a5cc3.wav
#   inflating: dataset/audios/30e8ee66.wav
#   inflating: dataset/audios/f417b1e4.wav
#   inflating: dataset/audios/17bccba6.wav
#   inflating: dataset/audios/a7ea7a8d.wav
#   inflating: dataset/audios/16b49662.wav
#   inflating: dataset/audios/f479e7f9.wav
#   inflating: dataset/audios/92702b88.wav
#   inflating: dataset/audios/1b033cd6.wav
#   inflating: dataset/audios/c64c9c15.wav
#   inflating: dataset/audios/14778c22.wav
#   inflating: dataset/audios/c4ceb0c0.wav
#   inflating: dataset/audios/b2c90347.wav
#   inflating: dataset/audios/c3b90ceb.wav
#   inflating: dataset/audios/499eb4e5.wav
#   inflating: dataset/audios/279b2071.wav
#   inflating: dataset/audios/fae62f56.wav
#   inflating: dataset/audios/6721e921.wav
#   inflating: dataset/audios/acbb5ca4.wav
#   inflating: dataset/audios/46bd52a4.wav
#   inflating: dataset/audios/1db95302.wav
#   inflating: dataset/audios/584b9a32.wav
#   inflating: dataset/audios/b4b3de11.wav
#   inflating: dataset/audios/8f345d22.wav
#   inflating: dataset/audios/deb78815.wav
#   inflating: dataset/audios/55dbe2e7.wav
#   inflating: dataset/audios/963b7038.wav
#   inflating: dataset/audios/078987a1.wav
#   inflating: dataset/audios/33eb501f.wav
#   inflating: dataset/audios/cb0679bf.wav
#   inflating: dataset/audios/5ef71aad.wav
#   inflating: dataset/audios/7d413a44.wav
#   inflating: dataset/audios/1d0d3df0.wav
#   inflating: dataset/audios/2ffda273.wav
#   inflating: dataset/audios/ee1e3293.wav
#   inflating: dataset/audios/b500c0af.wav
#   inflating: dataset/audios/5602171b.wav
#   inflating: dataset/audios/cf08afd3.wav
#   inflating: dataset/audios/b1d8010d.wav
#   inflating: dataset/audios/bd590943.wav
#   inflating: dataset/audios/2a5d34c8.wav
#   inflating: dataset/audios/b993baba.wav
#   inflating: dataset/audios/efcfca56.wav
#   inflating: dataset/audios/9e8c95e3.wav
#   inflating: dataset/audios/f2108262.wav
#   inflating: dataset/audios/ecf14238.wav
#   inflating: dataset/audios/e1dc44f4.wav
#   inflating: dataset/audios/c580abd5.wav
#   inflating: dataset/audios/e7848dbf.wav
#   inflating: dataset/audios/5cf3f9f2.wav
#   inflating: dataset/audios/b2d48b5f.wav
#   inflating: dataset/audios/2de86075.wav
#   inflating: dataset/audios/a5e041fb.wav
#   inflating: dataset/audios/87fe8193.wav

# %%
# realizo todos los imports que necesito
# - cada import es una libreria que contiene modulos que puedo usar
# - a su vez, puedo no importar toda la libreria sino solo un modulo 
#   * es el caso de la primera: "from pathlib import Path"
#   * es decir que de la libreria "pathlib" importe el modulo "Path"
from pathlib import Path
import IPython.display as ipd
import librosa
import pandas as pd # pandas por lo general se importa asi!
import numpy as np # lo mismo para numpy!

# %%
# Google Colab también tiene un sistema de archivos.
# El unzip que hicimos antes, descomprime los audios + un diccionario a una carpeta dentro del file system de Google Colab
# Llamo a esas carpetas y la guardo en la variable "AUDIOS_FOLDER"
DATA = Path('dataset/')
AUDIOS_FOLDER = DATA/'audios'

# %%
# dentro de la carpeta "DATA" abro el CSV que contiene el nombre del archivo y unas etiquetas que indican a que se refieren (el diccionario)
# notar que con "pd" hago mencion a Pandas, y le pido que haga un "read_csv", es decir, que lea un CSV
# ademas, le indico que lea las columnas "fname" y "labels"
annotations = pd.read_csv(DATA/'train.csv')[['fname', 'labels']] # el diccionario se llama "train.csv"
annotations.head(12) # esto me devuelve los primeros 12 resultados de la lectura del CSV
# Out:
#            fname                 labels
# 0   001ec0ad.wav        Finger_snapping
# 1   0026f116.wav        Finger_snapping
# 2   030d5b55.wav        Finger_snapping
# 3   037b9243.wav  Marimba_and_xylophone
# 4   03ea2668.wav        Finger_snapping
# 5   03f91aaf.wav          Keys_jangling
# 6   04eb6226.wav  Marimba_and_xylophone
# 7   0595bce6.wav  Marimba_and_xylophone
# 8   069d8df9.wav        Finger_snapping
# 9   076f25a3.wav          Keys_jangling
# 10  078987a1.wav  Marimba_and_xylophone
# 11  07cc5d69.wav  Marimba_and_xylophone

# %%
# Escuchamos audios
# https://librosa.org/doc/main/generated/librosa.load.html -> cuando queremos saber que hace una funcion o libreria
X_train = annotations['fname'].apply(lambda x: AUDIOS_FOLDER/x).values # guardo todos los nombres de los archivos en "X_train"
i = 6 # este sera el indice del audio a escuchar

# "librosa" me permite recuperar la serie temporal del audio seleccionado y luego, lo guardado en "X_i"
# en la definicion de la libreria, define serie temporal de la siguiente manera:
#     "time series: Typically an audio signal, denoted by y, and represented as a one-dimensional numpy.ndarray of floating-point values. 
#      y[t] corresponds to the amplitude of the waveform at sample t."
X_i, sr = librosa.load(X_train[i], sr = None) 
ipd.Audio(X_i.reshape(-1), rate = sr) # para que me aparezca el reproductor
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
len(X_i) # muestra la cantidad de amplitudes que tiene el vector X_i
# Out:
# 71168

# %%
# que hace el siguiente codigo?
cnt = 0
#for i in X_i:
#  if cnt < 100:
#    print(i)
#    cnt = cnt + 1

for i in X_i:
  if cnt > 16000 and cnt < 16500:
    print(cnt, i)
  cnt = cnt + 1

# %%
import matplotlib.pyplot as plt
largo=len(X_i)
y = X_i[0:largo]
x = range(0, largo, 1)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
time = np.arange(0,len(X_i))/sr
fig, ax = plt.subplots()
ax.plot(time, X_i)
ax.set(xlabel = 'Time(s)', ylabel = 'sound amplitude')
plt.show()
